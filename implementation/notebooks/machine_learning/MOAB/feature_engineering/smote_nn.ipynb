# %% [markdown]
# ## KNN Approach

# %% [markdown]
# ### Setup

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets

from pathlib import Path
import os

import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler


from pyMLaux import plot_history, evaluate_classification_result,plot_2d_prediction
# Out:
# 2024-05-06 22:29:06.373290: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-06 22:29:06.488471: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-06 22:29:06.488532: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-06 22:29:06.490515: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-06 22:29:06.503819: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-06 22:29:09.033210: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# read dynamic path
base_dir = Path(os.getcwd())/"implementation"
data_dir = base_dir / "data/source/"
result_dir = base_dir / "data/results/"

# %% [markdown]
# ### load & prepare dataset

# %% [markdown]
# the following code needs to be adapted for each protein-ligand complex individually

# %%
nn_data_raw_train = pd.read_csv(data_dir / "MOAB/moab_smote_train.csv")
nn_data_raw_test = pd.read_csv(data_dir / "MOAB/moab_smote_test.csv")

# %%
nn_data_train = {'data': np.array(nn_data_raw_train.iloc[:, 2:-1]),
             'target': np.array(nn_data_raw_train.iloc[0:,-1]),
             'feature_names': nn_data_raw_train.columns[2:-1],
             'target_names': ['inactive', 'active']}

nn_data_test = {'data': np.array(nn_data_raw_test.iloc[:, 2:-1]),
             'target': np.array(nn_data_raw_test.iloc[0:,-1]),
             'feature_names': nn_data_raw_test.columns[2:-1],
             'target_names': ['inactive', 'active']}

# %% [markdown]
# ### train and apply neural network

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(nn_data_train['data'].shape[1], )),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# 2024-05-06 22:29:12.376373: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:29:12.443291: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:29:12.443473: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:29:12.455740: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:29:12.456026: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:29:12.456117: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:29:12.923575: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:29:12.923686: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:29:12.923696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-05-06 22:29:12.923741: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 60
#
# =================================================================
# Total params: 60 (240.00 Byte)
# Trainable params: 60 (240.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# :01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:29:12.923765: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 559 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
history = model.fit(x=nn_data_train["data"], y=nn_data_train["target"], epochs=150, batch_size=16, validation_split=0.2, verbose=2)
plot_history(history)
# Out:
# Epoch 1/150
# 2024-05-06 22:29:15.084531: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-06 22:29:15.465351: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fe7b8914070 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-06 22:29:15.465387: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2024-05-06 22:29:15.469730: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-06 22:29:15.488268: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715027355.567707   13876 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 13/13 - 1s - loss: 0.7730 - accuracy: 0.4300 - val_loss: 0.7381 - val_accuracy: 0.4808 - 1s/epoch - 110ms/step
# Epoch 2/150
# 13/13 - 0s - loss: 0.7519 - accuracy: 0.4589 - val_loss: 0.7138 - val_accuracy: 0.5385 - 90ms/epoch - 7ms/step
# Epoch 3/150
# 13/13 - 0s - loss: 0.7374 - accuracy: 0.4541 - val_loss: 0.6969 - val_accuracy: 0.5577 - 87ms/epoch - 7ms/step
# Epoch 4/150
# 13/13 - 0s - loss: 0.7279 - accuracy: 0.4879 - val_loss: 0.6822 - val_accuracy: 0.5385 - 90ms/epoch - 7ms/step
# Epoch 5/150
# 13/13 - 0s - loss: 0.7197 - accuracy: 0.5072 - val_loss: 0.6728 - val_accuracy: 0.5385 - 83ms/epoch - 6ms/step
# Epoch 6/150
# 13/13 - 0s - loss: 0.7123 - accuracy: 0.5169 - val_loss: 0.6671 - val_accuracy: 0.5385 - 100ms/epoch - 8ms/step
# Epoch 7/150
# 13/13 - 0s - loss: 0.7063 - accuracy: 0.5266 - val_loss: 0.6629 - val_accuracy: 0.5577 - 92ms/epoch - 7ms/step
# Epoch 8/150
# 13/13 - 0s - loss: 0.7002 - accuracy: 0.5314 - val_loss: 0.6584 - val_accuracy: 0.5577 - 97ms/epoch - 7ms/step
# Epoch 9/150
# 13/13 - 0s - loss: 0.6947 - accuracy: 0.5459 - val_loss: 0.6528 - val_accuracy: 0.5577 - 100ms/epoch - 8ms/step
# Epoch 10/150
# 13/13 - 0s - loss: 0.6895 - accuracy: 0.5604 - val_loss: 0.6491 - val_accuracy: 0.5577 - 80ms/epoch - 6ms/step
# Epoch 11/150
# 13/13 - 0s - loss: 0.6845 - accuracy: 0.5749 - val_loss: 0.6475 - val_accuracy: 0.5769 - 81ms/epoch - 6ms/step
# Epoch 12/150
# 13/13 - 0s - loss: 0.6785 - accuracy: 0.5894 - val_loss: 0.6438 - val_accuracy: 0.5962 - 88ms/epoch - 7ms/step
# Epoch 13/150
# 13/13 - 0s - loss: 0.6739 - accuracy: 0.5845 - val_loss: 0.6390 - val_accuracy: 0.5962 - 98ms/epoch - 8ms/step
# Epoch 14/150
# 13/13 - 0s - loss: 0.6692 - accuracy: 0.5942 - val_loss: 0.6362 - val_accuracy: 0.5962 - 86ms/epoch - 7ms/step
# Epoch 15/150
# 13/13 - 0s - loss: 0.6644 - accuracy: 0.6087 - val_loss: 0.6329 - val_accuracy: 0.5962 - 102ms/epoch - 8ms/step
# Epoch 16/150
# 13/13 - 0s - loss: 0.6599 - accuracy: 0.6135 - val_loss: 0.6312 - val_accuracy: 0.5962 - 107ms/epoch - 8ms/step
# Epoch 17/150
# 13/13 - 0s - loss: 0.6553 - accuracy: 0.6135 - val_loss: 0.6281 - val_accuracy: 0.5962 - 116ms/epoch - 9ms/step
# Epoch 18/150
# 13/13 - 0s - loss: 0.6512 - accuracy: 0.6280 - val_loss: 0.6252 - val_accuracy: 0.6154 - 111ms/epoch - 9ms/step
# Epoch 19/150
# 13/13 - 0s - loss: 0.6472 - accuracy: 0.6280 - val_loss: 0.6221 - val_accuracy: 0.6346 - 102ms/epoch - 8ms/step
# Epoch 20/150
# 13/13 - 0s - loss: 0.6436 - accuracy: 0.6377 - val_loss: 0.6189 - val_accuracy: 0.6346 - 104ms/epoch - 8ms/step
# Epoch 21/150
# 13/13 - 0s - loss: 0.6393 - accuracy: 0.6377 - val_loss: 0.6172 - val_accuracy: 0.6346 - 104ms/epoch - 8ms/step
# Epoch 22/150
# 13/13 - 0s - loss: 0.6362 - accuracy: 0.6473 - val_loss: 0.6146 - val_accuracy: 0.6538 - 100ms/epoch - 8ms/step
# Epoch 23/150
# 13/13 - 0s - loss: 0.6320 - accuracy: 0.6425 - val_loss: 0.6129 - val_accuracy: 0.6538 - 87ms/epoch - 7ms/step
# Epoch 24/150
# 13/13 - 0s - loss: 0.6285 - accuracy: 0.6473 - val_loss: 0.6113 - val_accuracy: 0.6538 - 83ms/epoch - 6ms/step
# Epoch 25/150
# 13/13 - 0s - loss: 0.6252 - accuracy: 0.6618 - val_loss: 0.6101 - val_accuracy: 0.6538 - 91ms/epoch - 7ms/step
# Epoch 26/150
# 13/13 - 0s - loss: 0.6218 - accuracy: 0.6667 - val_loss: 0.6073 - val_accuracy: 0.6538 - 90ms/epoch - 7ms/step
# Epoch 27/150
# 13/13 - 0s - loss: 0.6188 - accuracy: 0.6715 - val_loss: 0.6059 - val_accuracy: 0.6538 - 86ms/epoch - 7ms/step
# Epoch 28/150
# 13/13 - 0s - loss: 0.6157 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6923 - 82ms/epoch - 6ms/step
# Epoch 29/150
# 13/13 - 0s - loss: 0.6124 - accuracy: 0.6812 - val_loss: 0.6007 - val_accuracy: 0.6923 - 78ms/epoch - 6ms/step
# Epoch 30/150
# 13/13 - 0s - loss: 0.6097 - accuracy: 0.6860 - val_loss: 0.5988 - val_accuracy: 0.6923 - 88ms/epoch - 7ms/step
# Epoch 31/150
# 13/13 - 0s - loss: 0.6069 - accuracy: 0.6957 - val_loss: 0.5967 - val_accuracy: 0.7115 - 95ms/epoch - 7ms/step
# Epoch 32/150
# 13/13 - 0s - loss: 0.6042 - accuracy: 0.7005 - val_loss: 0.5961 - val_accuracy: 0.7115 - 81ms/epoch - 6ms/step
# Epoch 33/150
# 13/13 - 0s - loss: 0.6013 - accuracy: 0.7005 - val_loss: 0.5945 - val_accuracy: 0.7115 - 81ms/epoch - 6ms/step
# Epoch 34/150
# 13/13 - 0s - loss: 0.5987 - accuracy: 0.7053 - val_loss: 0.5921 - val_accuracy: 0.7115 - 87ms/epoch - 7ms/step
# Epoch 35/150
# 13/13 - 0s - loss: 0.5963 - accuracy: 0.7053 - val_loss: 0.5901 - val_accuracy: 0.7115 - 128ms/epoch - 10ms/step
# Epoch 36/150
# 13/13 - 0s - loss: 0.5937 - accuracy: 0.7198 - val_loss: 0.5894 - val_accuracy: 0.7115 - 123ms/epoch - 9ms/step
# Epoch 37/150
# 13/13 - 0s - loss: 0.5914 - accuracy: 0.7391 - val_loss: 0.5887 - val_accuracy: 0.7115 - 123ms/epoch - 9ms/step
# Epoch 38/150
# 13/13 - 0s - loss: 0.5889 - accuracy: 0.7440 - val_loss: 0.5871 - val_accuracy: 0.7115 - 121ms/epoch - 9ms/step
# Epoch 39/150
# 13/13 - 0s - loss: 0.5865 - accuracy: 0.7488 - val_loss: 0.5850 - val_accuracy: 0.7115 - 112ms/epoch - 9ms/step
# Epoch 40/150
# 13/13 - 0s - loss: 0.5845 - accuracy: 0.7585 - val_loss: 0.5838 - val_accuracy: 0.7115 - 122ms/epoch - 9ms/step
# Epoch 41/150
# 13/13 - 0s - loss: 0.5823 - accuracy: 0.7585 - val_loss: 0.5822 - val_accuracy: 0.7115 - 127ms/epoch - 10ms/step
# Epoch 42/150
# 13/13 - 0s - loss: 0.5800 - accuracy: 0.7633 - val_loss: 0.5804 - val_accuracy: 0.7115 - 118ms/epoch - 9ms/step
# Epoch 43/150
# 13/13 - 0s - loss: 0.5781 - accuracy: 0.7585 - val_loss: 0.5791 - val_accuracy: 0.7115 - 112ms/epoch - 9ms/step
# Epoch 44/150
# 13/13 - 0s - loss: 0.5760 - accuracy: 0.7633 - val_loss: 0.5780 - val_accuracy: 0.7115 - 110ms/epoch - 8ms/step
# Epoch 45/150
# 13/13 - 0s - loss: 0.5740 - accuracy: 0.7681 - val_loss: 0.5774 - val_accuracy: 0.7115 - 122ms/epoch - 9ms/step
# Epoch 46/150
# 13/13 - 0s - loss: 0.5722 - accuracy: 0.7681 - val_loss: 0.5761 - val_accuracy: 0.7308 - 121ms/epoch - 9ms/step
# Epoch 47/150
# 13/13 - 0s - loss: 0.5702 - accuracy: 0.7778 - val_loss: 0.5752 - val_accuracy: 0.7308 - 119ms/epoch - 9ms/step
# Epoch 48/150
# 13/13 - 0s - loss: 0.5684 - accuracy: 0.7826 - val_loss: 0.5744 - val_accuracy: 0.7308 - 133ms/epoch - 10ms/step
# Epoch 49/150
# 13/13 - 0s - loss: 0.5671 - accuracy: 0.7826 - val_loss: 0.5722 - val_accuracy: 0.7308 - 150ms/epoch - 12ms/step
# Epoch 50/150
# 13/13 - 0s - loss: 0.5648 - accuracy: 0.7826 - val_loss: 0.5713 - val_accuracy: 0.7308 - 131ms/epoch - 10ms/step
# Epoch 51/150
# 13/13 - 0s - loss: 0.5633 - accuracy: 0.7923 - val_loss: 0.5706 - val_accuracy: 0.7308 - 128ms/epoch - 10ms/step
# Epoch 52/150
# 13/13 - 0s - loss: 0.5615 - accuracy: 0.7971 - val_loss: 0.5698 - val_accuracy: 0.7308 - 125ms/epoch - 10ms/step
# Epoch 53/150
# 13/13 - 0s - loss: 0.5598 - accuracy: 0.8019 - val_loss: 0.5693 - val_accuracy: 0.7115 - 123ms/epoch - 9ms/step
# Epoch 54/150
# 13/13 - 0s - loss: 0.5582 - accuracy: 0.8019 - val_loss: 0.5691 - val_accuracy: 0.7115 - 137ms/epoch - 11ms/step
# Epoch 55/150
# 13/13 - 0s - loss: 0.5566 - accuracy: 0.8019 - val_loss: 0.5679 - val_accuracy: 0.7115 - 136ms/epoch - 10ms/step
# Epoch 56/150
# 13/13 - 0s - loss: 0.5557 - accuracy: 0.8019 - val_loss: 0.5655 - val_accuracy: 0.7115 - 146ms/epoch - 11ms/step
# Epoch 57/150
# 13/13 - 0s - loss: 0.5536 - accuracy: 0.8019 - val_loss: 0.5661 - val_accuracy: 0.7115 - 145ms/epoch - 11ms/step
# Epoch 58/150
# 13/13 - 0s - loss: 0.5523 - accuracy: 0.8068 - val_loss: 0.5660 - val_accuracy: 0.7115 - 141ms/epoch - 11ms/step
# Epoch 59/150
# 13/13 - 0s - loss: 0.5508 - accuracy: 0.8019 - val_loss: 0.5641 - val_accuracy: 0.7115 - 150ms/epoch - 12ms/step
# Epoch 60/150
# 13/13 - 0s - loss: 0.5492 - accuracy: 0.8068 - val_loss: 0.5632 - val_accuracy: 0.7115 - 150ms/epoch - 12ms/step
# Epoch 61/150
# 13/13 - 0s - loss: 0.5479 - accuracy: 0.8068 - val_loss: 0.5628 - val_accuracy: 0.7115 - 148ms/epoch - 11ms/step
# Epoch 62/150
# 13/13 - 0s - loss: 0.5463 - accuracy: 0.8068 - val_loss: 0.5620 - val_accuracy: 0.7115 - 149ms/epoch - 11ms/step
# Epoch 63/150
# 13/13 - 0s - loss: 0.5450 - accuracy: 0.8068 - val_loss: 0.5615 - val_accuracy: 0.7115 - 140ms/epoch - 11ms/step
# Epoch 64/150
# 13/13 - 0s - loss: 0.5437 - accuracy: 0.8068 - val_loss: 0.5601 - val_accuracy: 0.7115 - 147ms/epoch - 11ms/step
# Epoch 65/150
# 13/13 - 0s - loss: 0.5426 - accuracy: 0.7971 - val_loss: 0.5606 - val_accuracy: 0.7115 - 148ms/epoch - 11ms/step
# Epoch 66/150
# 13/13 - 0s - loss: 0.5411 - accuracy: 0.7971 - val_loss: 0.5596 - val_accuracy: 0.7115 - 132ms/epoch - 10ms/step
# Epoch 67/150
# 13/13 - 0s - loss: 0.5398 - accuracy: 0.8019 - val_loss: 0.5584 - val_accuracy: 0.7115 - 129ms/epoch - 10ms/step
# Epoch 68/150
# 13/13 - 0s - loss: 0.5385 - accuracy: 0.8019 - val_loss: 0.5575 - val_accuracy: 0.7115 - 137ms/epoch - 11ms/step
# Epoch 69/150
# 13/13 - 0s - loss: 0.5375 - accuracy: 0.7971 - val_loss: 0.5572 - val_accuracy: 0.7115 - 130ms/epoch - 10ms/step
# Epoch 70/150
# 13/13 - 0s - loss: 0.5362 - accuracy: 0.7971 - val_loss: 0.5567 - val_accuracy: 0.7115 - 125ms/epoch - 10ms/step
# Epoch 71/150
# 13/13 - 0s - loss: 0.5354 - accuracy: 0.7971 - val_loss: 0.5554 - val_accuracy: 0.7115 - 122ms/epoch - 9ms/step
# Epoch 72/150
# 13/13 - 0s - loss: 0.5341 - accuracy: 0.8019 - val_loss: 0.5560 - val_accuracy: 0.7115 - 138ms/epoch - 11ms/step
# Epoch 73/150
# 13/13 - 0s - loss: 0.5327 - accuracy: 0.7971 - val_loss: 0.5557 - val_accuracy: 0.7115 - 130ms/epoch - 10ms/step
# Epoch 74/150
# 13/13 - 0s - loss: 0.5314 - accuracy: 0.7971 - val_loss: 0.5550 - val_accuracy: 0.7115 - 131ms/epoch - 10ms/step
# Epoch 75/150
# 13/13 - 0s - loss: 0.5303 - accuracy: 0.7971 - val_loss: 0.5537 - val_accuracy: 0.7115 - 134ms/epoch - 10ms/step
# Epoch 76/150
# 13/13 - 0s - loss: 0.5293 - accuracy: 0.7971 - val_loss: 0.5535 - val_accuracy: 0.7115 - 161ms/epoch - 12ms/step
# Epoch 77/150
# 13/13 - 0s - loss: 0.5282 - accuracy: 0.7971 - val_loss: 0.5527 - val_accuracy: 0.7115 - 160ms/epoch - 12ms/step
# Epoch 78/150
# 13/13 - 0s - loss: 0.5271 - accuracy: 0.7923 - val_loss: 0.5525 - val_accuracy: 0.7115 - 159ms/epoch - 12ms/step
# Epoch 79/150
# 13/13 - 0s - loss: 0.5260 - accuracy: 0.7923 - val_loss: 0.5524 - val_accuracy: 0.7115 - 145ms/epoch - 11ms/step
# Epoch 80/150
# 13/13 - 0s - loss: 0.5254 - accuracy: 0.7923 - val_loss: 0.5515 - val_accuracy: 0.7115 - 138ms/epoch - 11ms/step
# Epoch 81/150
# 13/13 - 0s - loss: 0.5242 - accuracy: 0.7923 - val_loss: 0.5518 - val_accuracy: 0.7308 - 146ms/epoch - 11ms/step
# Epoch 82/150
# 13/13 - 0s - loss: 0.5229 - accuracy: 0.7923 - val_loss: 0.5515 - val_accuracy: 0.7308 - 137ms/epoch - 11ms/step
# Epoch 83/150
# 13/13 - 0s - loss: 0.5226 - accuracy: 0.7923 - val_loss: 0.5497 - val_accuracy: 0.7308 - 149ms/epoch - 11ms/step
# Epoch 84/150
# 13/13 - 0s - loss: 0.5211 - accuracy: 0.7923 - val_loss: 0.5500 - val_accuracy: 0.7308 - 148ms/epoch - 11ms/step
# Epoch 85/150
# 13/13 - 0s - loss: 0.5206 - accuracy: 0.7923 - val_loss: 0.5509 - val_accuracy: 0.7308 - 144ms/epoch - 11ms/step
# Epoch 86/150
# 13/13 - 0s - loss: 0.5194 - accuracy: 0.7923 - val_loss: 0.5497 - val_accuracy: 0.7308 - 164ms/epoch - 13ms/step
# Epoch 87/150
# 13/13 - 0s - loss: 0.5181 - accuracy: 0.7923 - val_loss: 0.5489 - val_accuracy: 0.7308 - 154ms/epoch - 12ms/step
# Epoch 88/150
# 13/13 - 0s - loss: 0.5171 - accuracy: 0.7923 - val_loss: 0.5483 - val_accuracy: 0.7308 - 147ms/epoch - 11ms/step
# Epoch 89/150
# 13/13 - 0s - loss: 0.5162 - accuracy: 0.7923 - val_loss: 0.5482 - val_accuracy: 0.7308 - 151ms/epoch - 12ms/step
# Epoch 90/150
# 13/13 - 0s - loss: 0.5156 - accuracy: 0.7923 - val_loss: 0.5488 - val_accuracy: 0.7308 - 139ms/epoch - 11ms/step
# Epoch 91/150
# 13/13 - 0s - loss: 0.5148 - accuracy: 0.7923 - val_loss: 0.5470 - val_accuracy: 0.7308 - 154ms/epoch - 12ms/step
# Epoch 92/150
# 13/13 - 0s - loss: 0.5138 - accuracy: 0.7923 - val_loss: 0.5478 - val_accuracy: 0.7308 - 184ms/epoch - 14ms/step
# Epoch 93/150
# 13/13 - 0s - loss: 0.5128 - accuracy: 0.7923 - val_loss: 0.5474 - val_accuracy: 0.7308 - 149ms/epoch - 11ms/step
# Epoch 94/150
# 13/13 - 0s - loss: 0.5118 - accuracy: 0.7923 - val_loss: 0.5468 - val_accuracy: 0.7308 - 147ms/epoch - 11ms/step
# Epoch 95/150
# 13/13 - 0s - loss: 0.5110 - accuracy: 0.7923 - val_loss: 0.5456 - val_accuracy: 0.7308 - 143ms/epoch - 11ms/step
# Epoch 96/150
# 13/13 - 0s - loss: 0.5103 - accuracy: 0.7923 - val_loss: 0.5464 - val_accuracy: 0.7308 - 146ms/epoch - 11ms/step
# Epoch 97/150
# 13/13 - 0s - loss: 0.5092 - accuracy: 0.7923 - val_loss: 0.5455 - val_accuracy: 0.7308 - 140ms/epoch - 11ms/step
# Epoch 98/150
# 13/13 - 0s - loss: 0.5086 - accuracy: 0.7923 - val_loss: 0.5451 - val_accuracy: 0.7308 - 133ms/epoch - 10ms/step
# Epoch 99/150
# 13/13 - 0s - loss: 0.5076 - accuracy: 0.7923 - val_loss: 0.5448 - val_accuracy: 0.7308 - 139ms/epoch - 11ms/step
# Epoch 100/150
# 13/13 - 0s - loss: 0.5068 - accuracy: 0.7923 - val_loss: 0.5457 - val_accuracy: 0.7308 - 131ms/epoch - 10ms/step
# Epoch 101/150
# 13/13 - 0s - loss: 0.5059 - accuracy: 0.7923 - val_loss: 0.5454 - val_accuracy: 0.7308 - 127ms/epoch - 10ms/step
# Epoch 102/150
# 13/13 - 0s - loss: 0.5053 - accuracy: 0.7971 - val_loss: 0.5453 - val_accuracy: 0.7308 - 139ms/epoch - 11ms/step
# Epoch 103/150
# 13/13 - 0s - loss: 0.5047 - accuracy: 0.7923 - val_loss: 0.5440 - val_accuracy: 0.7308 - 137ms/epoch - 11ms/step
# Epoch 104/150
# 13/13 - 0s - loss: 0.5036 - accuracy: 0.8019 - val_loss: 0.5435 - val_accuracy: 0.7115 - 137ms/epoch - 11ms/step
# Epoch 105/150
# 13/13 - 0s - loss: 0.5029 - accuracy: 0.7923 - val_loss: 0.5439 - val_accuracy: 0.7308 - 137ms/epoch - 11ms/step
# Epoch 106/150
# 13/13 - 0s - loss: 0.5021 - accuracy: 0.7971 - val_loss: 0.5439 - val_accuracy: 0.7308 - 136ms/epoch - 10ms/step
# Epoch 107/150
# 13/13 - 0s - loss: 0.5016 - accuracy: 0.7874 - val_loss: 0.5446 - val_accuracy: 0.7308 - 144ms/epoch - 11ms/step
# Epoch 108/150
# 13/13 - 0s - loss: 0.5006 - accuracy: 0.7874 - val_loss: 0.5440 - val_accuracy: 0.7308 - 136ms/epoch - 10ms/step
# Epoch 109/150
# 13/13 - 0s - loss: 0.5001 - accuracy: 0.7874 - val_loss: 0.5434 - val_accuracy: 0.7115 - 141ms/epoch - 11ms/step
# Epoch 110/150
# 13/13 - 0s - loss: 0.4992 - accuracy: 0.7971 - val_loss: 0.5435 - val_accuracy: 0.7115 - 155ms/epoch - 12ms/step
# Epoch 111/150
# 13/13 - 0s - loss: 0.4986 - accuracy: 0.7971 - val_loss: 0.5423 - val_accuracy: 0.7115 - 151ms/epoch - 12ms/step
# Epoch 112/150
# 13/13 - 0s - loss: 0.4976 - accuracy: 0.7971 - val_loss: 0.5430 - val_accuracy: 0.7115 - 142ms/epoch - 11ms/step
# Epoch 113/150
# 13/13 - 0s - loss: 0.4977 - accuracy: 0.7971 - val_loss: 0.5414 - val_accuracy: 0.7115 - 157ms/epoch - 12ms/step
# Epoch 114/150
# 13/13 - 0s - loss: 0.4962 - accuracy: 0.7971 - val_loss: 0.5425 - val_accuracy: 0.7115 - 160ms/epoch - 12ms/step
# Epoch 115/150
# 13/13 - 0s - loss: 0.4960 - accuracy: 0.7923 - val_loss: 0.5435 - val_accuracy: 0.7308 - 152ms/epoch - 12ms/step
# Epoch 116/150
# 13/13 - 0s - loss: 0.4951 - accuracy: 0.7971 - val_loss: 0.5423 - val_accuracy: 0.7115 - 154ms/epoch - 12ms/step
# Epoch 117/150
# 13/13 - 0s - loss: 0.4945 - accuracy: 0.7971 - val_loss: 0.5413 - val_accuracy: 0.7115 - 167ms/epoch - 13ms/step
# Epoch 118/150
# 13/13 - 0s - loss: 0.4936 - accuracy: 0.7971 - val_loss: 0.5421 - val_accuracy: 0.7115 - 162ms/epoch - 12ms/step
# Epoch 119/150
# 13/13 - 0s - loss: 0.4928 - accuracy: 0.7971 - val_loss: 0.5419 - val_accuracy: 0.7308 - 153ms/epoch - 12ms/step
# Epoch 120/150
# 13/13 - 0s - loss: 0.4923 - accuracy: 0.7971 - val_loss: 0.5424 - val_accuracy: 0.7308 - 159ms/epoch - 12ms/step
# Epoch 121/150
# 13/13 - 0s - loss: 0.4917 - accuracy: 0.7971 - val_loss: 0.5424 - val_accuracy: 0.7308 - 168ms/epoch - 13ms/step
# Epoch 122/150
# 13/13 - 0s - loss: 0.4915 - accuracy: 0.7971 - val_loss: 0.5406 - val_accuracy: 0.7115 - 161ms/epoch - 12ms/step
# Epoch 123/150
# 13/13 - 0s - loss: 0.4902 - accuracy: 0.7971 - val_loss: 0.5406 - val_accuracy: 0.7115 - 153ms/epoch - 12ms/step
# Epoch 124/150
# 13/13 - 0s - loss: 0.4897 - accuracy: 0.7971 - val_loss: 0.5413 - val_accuracy: 0.7308 - 143ms/epoch - 11ms/step
# Epoch 125/150
# 13/13 - 0s - loss: 0.4892 - accuracy: 0.7971 - val_loss: 0.5417 - val_accuracy: 0.7308 - 154ms/epoch - 12ms/step
# Epoch 126/150
# 13/13 - 0s - loss: 0.4883 - accuracy: 0.7971 - val_loss: 0.5415 - val_accuracy: 0.7308 - 137ms/epoch - 11ms/step
# Epoch 127/150
# 13/13 - 0s - loss: 0.4879 - accuracy: 0.7971 - val_loss: 0.5410 - val_accuracy: 0.7308 - 138ms/epoch - 11ms/step
# Epoch 128/150
# 13/13 - 0s - loss: 0.4870 - accuracy: 0.7971 - val_loss: 0.5406 - val_accuracy: 0.7308 - 134ms/epoch - 10ms/step
# Epoch 129/150
# 13/13 - 0s - loss: 0.4864 - accuracy: 0.7971 - val_loss: 0.5405 - val_accuracy: 0.7308 - 144ms/epoch - 11ms/step
# Epoch 130/150
# 13/13 - 0s - loss: 0.4859 - accuracy: 0.7923 - val_loss: 0.5401 - val_accuracy: 0.7308 - 128ms/epoch - 10ms/step
# Epoch 131/150
# 13/13 - 0s - loss: 0.4853 - accuracy: 0.7971 - val_loss: 0.5401 - val_accuracy: 0.7308 - 143ms/epoch - 11ms/step
# Epoch 132/150
# 13/13 - 0s - loss: 0.4848 - accuracy: 0.8019 - val_loss: 0.5397 - val_accuracy: 0.7308 - 144ms/epoch - 11ms/step
# Epoch 133/150
# 13/13 - 0s - loss: 0.4842 - accuracy: 0.7971 - val_loss: 0.5404 - val_accuracy: 0.7308 - 149ms/epoch - 11ms/step
# Epoch 134/150
# 13/13 - 0s - loss: 0.4842 - accuracy: 0.7971 - val_loss: 0.5418 - val_accuracy: 0.7308 - 138ms/epoch - 11ms/step
# Epoch 135/150
# 13/13 - 0s - loss: 0.4838 - accuracy: 0.7971 - val_loss: 0.5398 - val_accuracy: 0.7308 - 146ms/epoch - 11ms/step
# Epoch 136/150
# 13/13 - 0s - loss: 0.4824 - accuracy: 0.7971 - val_loss: 0.5402 - val_accuracy: 0.7308 - 156ms/epoch - 12ms/step
# Epoch 137/150
# 13/13 - 0s - loss: 0.4822 - accuracy: 0.7971 - val_loss: 0.5396 - val_accuracy: 0.7308 - 153ms/epoch - 12ms/step
# Epoch 138/150
# 13/13 - 0s - loss: 0.4814 - accuracy: 0.8019 - val_loss: 0.5406 - val_accuracy: 0.7308 - 139ms/epoch - 11ms/step
# Epoch 139/150
# 13/13 - 0s - loss: 0.4808 - accuracy: 0.8019 - val_loss: 0.5410 - val_accuracy: 0.7308 - 157ms/epoch - 12ms/step
# Epoch 140/150
# 13/13 - 0s - loss: 0.4802 - accuracy: 0.8019 - val_loss: 0.5407 - val_accuracy: 0.7308 - 136ms/epoch - 10ms/step
# Epoch 141/150
# 13/13 - 0s - loss: 0.4797 - accuracy: 0.8019 - val_loss: 0.5405 - val_accuracy: 0.7308 - 140ms/epoch - 11ms/step
# Epoch 142/150
# 13/13 - 0s - loss: 0.4791 - accuracy: 0.8019 - val_loss: 0.5405 - val_accuracy: 0.7308 - 163ms/epoch - 13ms/step
# Epoch 143/150
# 13/13 - 0s - loss: 0.4786 - accuracy: 0.8019 - val_loss: 0.5403 - val_accuracy: 0.7308 - 159ms/epoch - 12ms/step
# Epoch 144/150
# 13/13 - 0s - loss: 0.4782 - accuracy: 0.8068 - val_loss: 0.5392 - val_accuracy: 0.7308 - 148ms/epoch - 11ms/step
# Epoch 145/150
# 13/13 - 0s - loss: 0.4776 - accuracy: 0.8019 - val_loss: 0.5399 - val_accuracy: 0.7308 - 153ms/epoch - 12ms/step
# Epoch 146/150
# 13/13 - 0s - loss: 0.4770 - accuracy: 0.8019 - val_loss: 0.5402 - val_accuracy: 0.7308 - 153ms/epoch - 12ms/step
# Epoch 147/150
# 13/13 - 0s - loss: 0.4765 - accuracy: 0.8019 - val_loss: 0.5403 - val_accuracy: 0.7308 - 130ms/epoch - 10ms/step
# Epoch 148/150
# 13/13 - 0s - loss: 0.4760 - accuracy: 0.8019 - val_loss: 0.5401 - val_accuracy: 0.7308 - 132ms/epoch - 10ms/step
# Epoch 149/150
# 13/13 - 0s - loss: 0.4754 - accuracy: 0.8019 - val_loss: 0.5399 - val_accuracy: 0.7308 - 157ms/epoch - 12ms/step
# Epoch 150/150
# 13/13 - 0s - loss: 0.4750 - accuracy: 0.8068 - val_loss: 0.5393 - val_accuracy: 0.7308 - 157ms/epoch - 12ms/step

# %% [markdown]
# ### Evaluate Testdata using model

# %%
pred = model.predict(nn_data_test["data"])
classes= [1 if i > 0.5  else 0 for i in pred]
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %% [markdown]
# ### Prepare Data for evaluation

# %%
result_df = pd.DataFrame(columns=nn_data_raw_train.columns[:-1])

for i, row in enumerate(nn_data_test["data"]):
    data = [i,i]
    data.extend(row)
    result_df.loc[i+1] = data

result_df["LABEL"] = nn_data_test["target"]
result_df["PRED"] = classes

result_df.to_csv(result_dir / "MOAB/fe_smote_nn.csv", encoding="utf-8")
