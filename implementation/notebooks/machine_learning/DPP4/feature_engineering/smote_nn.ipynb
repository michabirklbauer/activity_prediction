# %% [markdown]
# ## KNN Approach

# %% [markdown]
# ### Setup

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets

from pathlib import Path
import os

import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler


from pyMLaux import plot_history, evaluate_classification_result,plot_2d_prediction
# Out:
# 2024-05-06 22:26:50.652286: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-06 22:26:50.687206: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-06 22:26:50.687246: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-06 22:26:50.688470: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-06 22:26:50.697053: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-06 22:26:51.418892: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# read dynamic path
base_dir = Path(os.getcwd())/"implementation"
data_dir = base_dir / "data/source/"
result_dir = base_dir / "data/results/"

# %% [markdown]
# ### load & prepare dataset

# %% [markdown]
# the following code needs to be adapted for each protein-ligand complex individually

# %%
nn_data_raw_train = pd.read_csv(data_dir / "DPP4/dpp4_smote_train.csv")
nn_data_raw_test = pd.read_csv(data_dir / "DPP4/dpp4_smote_test.csv")

# %%
nn_data_train = {'data': np.array(nn_data_raw_train.iloc[:, 2:-1]),
             'target': np.array(nn_data_raw_train.iloc[0:,-1]),
             'feature_names': nn_data_raw_train.columns[2:-1],
             'target_names': ['inactive', 'active']}

nn_data_test = {'data': np.array(nn_data_raw_test.iloc[:, 2:-1]),
             'target': np.array(nn_data_raw_test.iloc[0:,-1]),
             'feature_names': nn_data_raw_test.columns[2:-1],
             'target_names': ['inactive', 'active']}

# %% [markdown]
# ### train and apply neural network

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(nn_data_train['data'].shape[1], )),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# 2024-05-06 22:26:52.488526: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:26:52.530822: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:26:52.530877: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:26:52.535112: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:26:52.535182: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:26:52.535201: I external/local_xla/xla/stream_executor
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 121
#
# =================================================================
# Total params: 121 (484.00 Byte)
# Trainable params: 121 (484.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# /cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:26:52.827281: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:26:52.827362: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:26:52.827369: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-05-06 22:26:52.827400: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-06 22:26:52.827418: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 842 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
history = model.fit(x=nn_data_train["data"], y=nn_data_train["target"], epochs=150, batch_size=16, validation_split=0.2, verbose=2)
plot_history(history)
# Out:
# Epoch 1/150
# 2024-05-06 22:26:55.231572: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-06 22:26:55.575584: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f2732cdc3f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-06 22:26:55.575620: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2024-05-06 22:26:55.580542: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-06 22:26:55.595158: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715027215.725944    9099 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 60/60 - 2s - loss: 0.6905 - accuracy: 0.5570 - val_loss: 0.6776 - val_accuracy: 0.5630 - 2s/epoch - 26ms/step
# Epoch 2/150
# 60/60 - 0s - loss: 0.6760 - accuracy: 0.5738 - val_loss: 0.6709 - val_accuracy: 0.5882 - 243ms/epoch - 4ms/step
# Epoch 3/150
# 60/60 - 0s - loss: 0.6654 - accuracy: 0.5886 - val_loss: 0.6633 - val_accuracy: 0.5924 - 247ms/epoch - 4ms/step
# Epoch 4/150
# 60/60 - 0s - loss: 0.6559 - accuracy: 0.6108 - val_loss: 0.6571 - val_accuracy: 0.6176 - 302ms/epoch - 5ms/step
# Epoch 5/150
# 60/60 - 0s - loss: 0.6472 - accuracy: 0.6308 - val_loss: 0.6485 - val_accuracy: 0.6303 - 259ms/epoch - 4ms/step
# Epoch 6/150
# 60/60 - 0s - loss: 0.6396 - accuracy: 0.6424 - val_loss: 0.6427 - val_accuracy: 0.6597 - 251ms/epoch - 4ms/step
# Epoch 7/150
# 60/60 - 0s - loss: 0.6324 - accuracy: 0.6603 - val_loss: 0.6372 - val_accuracy: 0.6723 - 256ms/epoch - 4ms/step
# Epoch 8/150
# 60/60 - 0s - loss: 0.6253 - accuracy: 0.6709 - val_loss: 0.6330 - val_accuracy: 0.6891 - 257ms/epoch - 4ms/step
# Epoch 9/150
# 60/60 - 0s - loss: 0.6193 - accuracy: 0.6751 - val_loss: 0.6273 - val_accuracy: 0.7017 - 304ms/epoch - 5ms/step
# Epoch 10/150
# 60/60 - 0s - loss: 0.6138 - accuracy: 0.6825 - val_loss: 0.6203 - val_accuracy: 0.7101 - 271ms/epoch - 5ms/step
# Epoch 11/150
# 60/60 - 0s - loss: 0.6085 - accuracy: 0.6920 - val_loss: 0.6166 - val_accuracy: 0.7017 - 280ms/epoch - 5ms/step
# Epoch 12/150
# 60/60 - 0s - loss: 0.6038 - accuracy: 0.6973 - val_loss: 0.6132 - val_accuracy: 0.7059 - 441ms/epoch - 7ms/step
# Epoch 13/150
# 60/60 - 0s - loss: 0.5992 - accuracy: 0.7025 - val_loss: 0.6096 - val_accuracy: 0.7017 - 457ms/epoch - 8ms/step
# Epoch 14/150
# 60/60 - 0s - loss: 0.5947 - accuracy: 0.7036 - val_loss: 0.6059 - val_accuracy: 0.7059 - 480ms/epoch - 8ms/step
# Epoch 15/150
# 60/60 - 0s - loss: 0.5907 - accuracy: 0.7078 - val_loss: 0.6026 - val_accuracy: 0.7101 - 454ms/epoch - 8ms/step
# Epoch 16/150
# 60/60 - 0s - loss: 0.5868 - accuracy: 0.7131 - val_loss: 0.5988 - val_accuracy: 0.7143 - 465ms/epoch - 8ms/step
# Epoch 17/150
# 60/60 - 0s - loss: 0.5834 - accuracy: 0.7152 - val_loss: 0.5965 - val_accuracy: 0.7185 - 477ms/epoch - 8ms/step
# Epoch 18/150
# 60/60 - 1s - loss: 0.5805 - accuracy: 0.7268 - val_loss: 0.5926 - val_accuracy: 0.7227 - 501ms/epoch - 8ms/step
# Epoch 19/150
# 60/60 - 1s - loss: 0.5770 - accuracy: 0.7289 - val_loss: 0.5909 - val_accuracy: 0.7227 - 715ms/epoch - 12ms/step
# Epoch 20/150
# 60/60 - 1s - loss: 0.5738 - accuracy: 0.7289 - val_loss: 0.5887 - val_accuracy: 0.7269 - 1s/epoch - 17ms/step
# Epoch 21/150
# 60/60 - 1s - loss: 0.5713 - accuracy: 0.7342 - val_loss: 0.5867 - val_accuracy: 0.7311 - 1s/epoch - 18ms/step
# Epoch 22/150
# 60/60 - 1s - loss: 0.5683 - accuracy: 0.7310 - val_loss: 0.5836 - val_accuracy: 0.7353 - 1s/epoch - 20ms/step
# Epoch 23/150
# 60/60 - 1s - loss: 0.5660 - accuracy: 0.7331 - val_loss: 0.5809 - val_accuracy: 0.7437 - 1s/epoch - 19ms/step
# Epoch 24/150
# 60/60 - 1s - loss: 0.5635 - accuracy: 0.7310 - val_loss: 0.5801 - val_accuracy: 0.7395 - 1s/epoch - 18ms/step
# Epoch 25/150
# 60/60 - 1s - loss: 0.5610 - accuracy: 0.7373 - val_loss: 0.5797 - val_accuracy: 0.7311 - 1s/epoch - 18ms/step
# Epoch 26/150
# 60/60 - 1s - loss: 0.5589 - accuracy: 0.7395 - val_loss: 0.5775 - val_accuracy: 0.7395 - 1s/epoch - 19ms/step
# Epoch 27/150
# 60/60 - 1s - loss: 0.5569 - accuracy: 0.7426 - val_loss: 0.5764 - val_accuracy: 0.7311 - 1s/epoch - 19ms/step
# Epoch 28/150
# 60/60 - 1s - loss: 0.5551 - accuracy: 0.7405 - val_loss: 0.5750 - val_accuracy: 0.7353 - 1s/epoch - 19ms/step
# Epoch 29/150
# 60/60 - 1s - loss: 0.5529 - accuracy: 0.7458 - val_loss: 0.5717 - val_accuracy: 0.7437 - 1s/epoch - 19ms/step
# Epoch 30/150
# 60/60 - 1s - loss: 0.5510 - accuracy: 0.7373 - val_loss: 0.5710 - val_accuracy: 0.7395 - 1s/epoch - 18ms/step
# Epoch 31/150
# 60/60 - 1s - loss: 0.5496 - accuracy: 0.7416 - val_loss: 0.5706 - val_accuracy: 0.7311 - 995ms/epoch - 17ms/step
# Epoch 32/150
# 60/60 - 1s - loss: 0.5478 - accuracy: 0.7437 - val_loss: 0.5688 - val_accuracy: 0.7311 - 1s/epoch - 18ms/step
# Epoch 33/150
# 60/60 - 1s - loss: 0.5465 - accuracy: 0.7426 - val_loss: 0.5679 - val_accuracy: 0.7353 - 1s/epoch - 18ms/step
# Epoch 34/150
# 60/60 - 1s - loss: 0.5448 - accuracy: 0.7437 - val_loss: 0.5648 - val_accuracy: 0.7479 - 1s/epoch - 18ms/step
# Epoch 35/150
# 60/60 - 1s - loss: 0.5433 - accuracy: 0.7447 - val_loss: 0.5655 - val_accuracy: 0.7395 - 1s/epoch - 17ms/step
# Epoch 36/150
# 60/60 - 1s - loss: 0.5419 - accuracy: 0.7489 - val_loss: 0.5631 - val_accuracy: 0.7437 - 997ms/epoch - 17ms/step
# Epoch 37/150
# 60/60 - 1s - loss: 0.5406 - accuracy: 0.7511 - val_loss: 0.5642 - val_accuracy: 0.7353 - 1s/epoch - 18ms/step
# Epoch 38/150
# 60/60 - 1s - loss: 0.5390 - accuracy: 0.7511 - val_loss: 0.5612 - val_accuracy: 0.7437 - 1s/epoch - 18ms/step
# Epoch 39/150
# 60/60 - 1s - loss: 0.5378 - accuracy: 0.7500 - val_loss: 0.5613 - val_accuracy: 0.7479 - 1s/epoch - 18ms/step
# Epoch 40/150
# 60/60 - 1s - loss: 0.5367 - accuracy: 0.7511 - val_loss: 0.5599 - val_accuracy: 0.7479 - 1s/epoch - 18ms/step
# Epoch 41/150
# 60/60 - 1s - loss: 0.5353 - accuracy: 0.7511 - val_loss: 0.5606 - val_accuracy: 0.7395 - 1s/epoch - 18ms/step
# Epoch 42/150
# 60/60 - 1s - loss: 0.5343 - accuracy: 0.7542 - val_loss: 0.5586 - val_accuracy: 0.7479 - 1s/epoch - 17ms/step
# Epoch 43/150
# 60/60 - 1s - loss: 0.5332 - accuracy: 0.7584 - val_loss: 0.5587 - val_accuracy: 0.7437 - 1s/epoch - 18ms/step
# Epoch 44/150
# 60/60 - 1s - loss: 0.5321 - accuracy: 0.7542 - val_loss: 0.5579 - val_accuracy: 0.7437 - 1s/epoch - 19ms/step
# Epoch 45/150
# 60/60 - 1s - loss: 0.5310 - accuracy: 0.7553 - val_loss: 0.5565 - val_accuracy: 0.7479 - 1s/epoch - 19ms/step
# Epoch 46/150
# 60/60 - 1s - loss: 0.5301 - accuracy: 0.7553 - val_loss: 0.5574 - val_accuracy: 0.7479 - 1s/epoch - 18ms/step
# Epoch 47/150
# 60/60 - 1s - loss: 0.5292 - accuracy: 0.7542 - val_loss: 0.5556 - val_accuracy: 0.7521 - 1s/epoch - 17ms/step
# Epoch 48/150
# 60/60 - 1s - loss: 0.5281 - accuracy: 0.7511 - val_loss: 0.5553 - val_accuracy: 0.7563 - 969ms/epoch - 16ms/step
# Epoch 49/150
# 60/60 - 1s - loss: 0.5275 - accuracy: 0.7574 - val_loss: 0.5573 - val_accuracy: 0.7479 - 964ms/epoch - 16ms/step
# Epoch 50/150
# 60/60 - 1s - loss: 0.5262 - accuracy: 0.7553 - val_loss: 0.5536 - val_accuracy: 0.7563 - 1s/epoch - 18ms/step
# Epoch 51/150
# 60/60 - 1s - loss: 0.5255 - accuracy: 0.7511 - val_loss: 0.5544 - val_accuracy: 0.7521 - 1s/epoch - 20ms/step
# Epoch 52/150
# 60/60 - 1s - loss: 0.5246 - accuracy: 0.7574 - val_loss: 0.5546 - val_accuracy: 0.7479 - 1s/epoch - 25ms/step
# Epoch 53/150
# 60/60 - 1s - loss: 0.5245 - accuracy: 0.7542 - val_loss: 0.5525 - val_accuracy: 0.7563 - 1s/epoch - 21ms/step
# Epoch 54/150
# 60/60 - 1s - loss: 0.5233 - accuracy: 0.7574 - val_loss: 0.5543 - val_accuracy: 0.7437 - 1s/epoch - 22ms/step
# Epoch 55/150
# 60/60 - 1s - loss: 0.5222 - accuracy: 0.7584 - val_loss: 0.5534 - val_accuracy: 0.7479 - 1s/epoch - 18ms/step
# Epoch 56/150
# 60/60 - 1s - loss: 0.5217 - accuracy: 0.7595 - val_loss: 0.5533 - val_accuracy: 0.7437 - 1s/epoch - 18ms/step
# Epoch 57/150
# 60/60 - 1s - loss: 0.5208 - accuracy: 0.7574 - val_loss: 0.5530 - val_accuracy: 0.7437 - 1s/epoch - 21ms/step
# Epoch 58/150
# 60/60 - 1s - loss: 0.5202 - accuracy: 0.7553 - val_loss: 0.5519 - val_accuracy: 0.7479 - 1s/epoch - 19ms/step
# Epoch 59/150
# 60/60 - 1s - loss: 0.5196 - accuracy: 0.7563 - val_loss: 0.5531 - val_accuracy: 0.7479 - 1s/epoch - 17ms/step
# Epoch 60/150
# 60/60 - 1s - loss: 0.5190 - accuracy: 0.7563 - val_loss: 0.5515 - val_accuracy: 0.7437 - 1s/epoch - 23ms/step
# Epoch 61/150
# 60/60 - 1s - loss: 0.5185 - accuracy: 0.7584 - val_loss: 0.5510 - val_accuracy: 0.7479 - 1s/epoch - 20ms/step
# Epoch 62/150
# 60/60 - 1s - loss: 0.5174 - accuracy: 0.7542 - val_loss: 0.5516 - val_accuracy: 0.7395 - 1s/epoch - 22ms/step
# Epoch 63/150
# 60/60 - 1s - loss: 0.5168 - accuracy: 0.7542 - val_loss: 0.5511 - val_accuracy: 0.7437 - 986ms/epoch - 16ms/step
# Epoch 64/150
# 60/60 - 1s - loss: 0.5167 - accuracy: 0.7542 - val_loss: 0.5494 - val_accuracy: 0.7521 - 784ms/epoch - 13ms/step
# Epoch 65/150
# 60/60 - 1s - loss: 0.5157 - accuracy: 0.7563 - val_loss: 0.5507 - val_accuracy: 0.7437 - 650ms/epoch - 11ms/step
# Epoch 66/150
# 60/60 - 1s - loss: 0.5152 - accuracy: 0.7553 - val_loss: 0.5520 - val_accuracy: 0.7395 - 570ms/epoch - 9ms/step
# Epoch 67/150
# 60/60 - 1s - loss: 0.5150 - accuracy: 0.7627 - val_loss: 0.5506 - val_accuracy: 0.7479 - 560ms/epoch - 9ms/step
# Epoch 68/150
# 60/60 - 1s - loss: 0.5140 - accuracy: 0.7553 - val_loss: 0.5503 - val_accuracy: 0.7479 - 571ms/epoch - 10ms/step
# Epoch 69/150
# 60/60 - 1s - loss: 0.5135 - accuracy: 0.7563 - val_loss: 0.5495 - val_accuracy: 0.7437 - 578ms/epoch - 10ms/step
# Epoch 70/150
# 60/60 - 1s - loss: 0.5132 - accuracy: 0.7595 - val_loss: 0.5485 - val_accuracy: 0.7395 - 593ms/epoch - 10ms/step
# Epoch 71/150
# 60/60 - 1s - loss: 0.5125 - accuracy: 0.7595 - val_loss: 0.5494 - val_accuracy: 0.7479 - 581ms/epoch - 10ms/step
# Epoch 72/150
# 60/60 - 1s - loss: 0.5121 - accuracy: 0.7605 - val_loss: 0.5495 - val_accuracy: 0.7521 - 542ms/epoch - 9ms/step
# Epoch 73/150
# 60/60 - 1s - loss: 0.5115 - accuracy: 0.7574 - val_loss: 0.5506 - val_accuracy: 0.7479 - 517ms/epoch - 9ms/step
# Epoch 74/150
# 60/60 - 0s - loss: 0.5111 - accuracy: 0.7595 - val_loss: 0.5506 - val_accuracy: 0.7437 - 492ms/epoch - 8ms/step
# Epoch 75/150
# 60/60 - 0s - loss: 0.5107 - accuracy: 0.7584 - val_loss: 0.5503 - val_accuracy: 0.7479 - 483ms/epoch - 8ms/step
# Epoch 76/150
# 60/60 - 0s - loss: 0.5102 - accuracy: 0.7605 - val_loss: 0.5512 - val_accuracy: 0.7437 - 489ms/epoch - 8ms/step
# Epoch 77/150
# 60/60 - 0s - loss: 0.5096 - accuracy: 0.7584 - val_loss: 0.5496 - val_accuracy: 0.7437 - 482ms/epoch - 8ms/step
# Epoch 78/150
# 60/60 - 0s - loss: 0.5092 - accuracy: 0.7627 - val_loss: 0.5515 - val_accuracy: 0.7437 - 492ms/epoch - 8ms/step
# Epoch 79/150
# 60/60 - 0s - loss: 0.5092 - accuracy: 0.7595 - val_loss: 0.5503 - val_accuracy: 0.7437 - 481ms/epoch - 8ms/step
# Epoch 80/150
# 60/60 - 1s - loss: 0.5087 - accuracy: 0.7563 - val_loss: 0.5514 - val_accuracy: 0.7437 - 526ms/epoch - 9ms/step
# Epoch 81/150
# 60/60 - 1s - loss: 0.5078 - accuracy: 0.7658 - val_loss: 0.5504 - val_accuracy: 0.7437 - 526ms/epoch - 9ms/step
# Epoch 82/150
# 60/60 - 1s - loss: 0.5074 - accuracy: 0.7616 - val_loss: 0.5510 - val_accuracy: 0.7437 - 554ms/epoch - 9ms/step
# Epoch 83/150
# 60/60 - 1s - loss: 0.5072 - accuracy: 0.7627 - val_loss: 0.5505 - val_accuracy: 0.7437 - 557ms/epoch - 9ms/step
# Epoch 84/150
# 60/60 - 1s - loss: 0.5067 - accuracy: 0.7658 - val_loss: 0.5506 - val_accuracy: 0.7437 - 565ms/epoch - 9ms/step
# Epoch 85/150
# 60/60 - 1s - loss: 0.5063 - accuracy: 0.7669 - val_loss: 0.5511 - val_accuracy: 0.7437 - 593ms/epoch - 10ms/step
# Epoch 86/150
# 60/60 - 1s - loss: 0.5058 - accuracy: 0.7648 - val_loss: 0.5499 - val_accuracy: 0.7437 - 644ms/epoch - 11ms/step
# Epoch 87/150
# 60/60 - 1s - loss: 0.5056 - accuracy: 0.7658 - val_loss: 0.5501 - val_accuracy: 0.7437 - 588ms/epoch - 10ms/step
# Epoch 88/150
# 60/60 - 1s - loss: 0.5052 - accuracy: 0.7679 - val_loss: 0.5504 - val_accuracy: 0.7437 - 551ms/epoch - 9ms/step
# Epoch 89/150
# 60/60 - 1s - loss: 0.5048 - accuracy: 0.7669 - val_loss: 0.5511 - val_accuracy: 0.7437 - 584ms/epoch - 10ms/step
# Epoch 90/150
# 60/60 - 1s - loss: 0.5046 - accuracy: 0.7616 - val_loss: 0.5502 - val_accuracy: 0.7437 - 582ms/epoch - 10ms/step
# Epoch 91/150
# 60/60 - 1s - loss: 0.5042 - accuracy: 0.7679 - val_loss: 0.5509 - val_accuracy: 0.7437 - 537ms/epoch - 9ms/step
# Epoch 92/150
# 60/60 - 1s - loss: 0.5038 - accuracy: 0.7679 - val_loss: 0.5503 - val_accuracy: 0.7437 - 506ms/epoch - 8ms/step
# Epoch 93/150
# 60/60 - 1s - loss: 0.5039 - accuracy: 0.7658 - val_loss: 0.5499 - val_accuracy: 0.7437 - 546ms/epoch - 9ms/step
# Epoch 94/150
# 60/60 - 1s - loss: 0.5038 - accuracy: 0.7637 - val_loss: 0.5514 - val_accuracy: 0.7437 - 533ms/epoch - 9ms/step
# Epoch 95/150
# 60/60 - 1s - loss: 0.5030 - accuracy: 0.7690 - val_loss: 0.5514 - val_accuracy: 0.7479 - 564ms/epoch - 9ms/step
# Epoch 96/150
# 60/60 - 1s - loss: 0.5028 - accuracy: 0.7648 - val_loss: 0.5512 - val_accuracy: 0.7479 - 581ms/epoch - 10ms/step
# Epoch 97/150
# 60/60 - 1s - loss: 0.5026 - accuracy: 0.7616 - val_loss: 0.5523 - val_accuracy: 0.7479 - 581ms/epoch - 10ms/step
# Epoch 98/150
# 60/60 - 1s - loss: 0.5021 - accuracy: 0.7648 - val_loss: 0.5518 - val_accuracy: 0.7437 - 575ms/epoch - 10ms/step
# Epoch 99/150
# 60/60 - 1s - loss: 0.5016 - accuracy: 0.7658 - val_loss: 0.5511 - val_accuracy: 0.7479 - 522ms/epoch - 9ms/step
# Epoch 100/150
# 60/60 - 1s - loss: 0.5013 - accuracy: 0.7658 - val_loss: 0.5517 - val_accuracy: 0.7437 - 534ms/epoch - 9ms/step
# Epoch 101/150
# 60/60 - 1s - loss: 0.5014 - accuracy: 0.7627 - val_loss: 0.5532 - val_accuracy: 0.7395 - 541ms/epoch - 9ms/step
# Epoch 102/150
# 60/60 - 1s - loss: 0.5007 - accuracy: 0.7637 - val_loss: 0.5525 - val_accuracy: 0.7437 - 557ms/epoch - 9ms/step
# Epoch 103/150
# 60/60 - 1s - loss: 0.5004 - accuracy: 0.7637 - val_loss: 0.5531 - val_accuracy: 0.7395 - 524ms/epoch - 9ms/step
# Epoch 104/150
# 60/60 - 1s - loss: 0.5003 - accuracy: 0.7679 - val_loss: 0.5530 - val_accuracy: 0.7353 - 586ms/epoch - 10ms/step
# Epoch 105/150
# 60/60 - 1s - loss: 0.5002 - accuracy: 0.7595 - val_loss: 0.5520 - val_accuracy: 0.7479 - 508ms/epoch - 8ms/step
# Epoch 106/150
# 60/60 - 1s - loss: 0.4997 - accuracy: 0.7637 - val_loss: 0.5527 - val_accuracy: 0.7395 - 529ms/epoch - 9ms/step
# Epoch 107/150
# 60/60 - 0s - loss: 0.4996 - accuracy: 0.7637 - val_loss: 0.5530 - val_accuracy: 0.7395 - 473ms/epoch - 8ms/step
# Epoch 108/150
# 60/60 - 1s - loss: 0.4994 - accuracy: 0.7648 - val_loss: 0.5536 - val_accuracy: 0.7311 - 506ms/epoch - 8ms/step
# Epoch 109/150
# 60/60 - 0s - loss: 0.4989 - accuracy: 0.7669 - val_loss: 0.5539 - val_accuracy: 0.7311 - 487ms/epoch - 8ms/step
# Epoch 110/150
# 60/60 - 1s - loss: 0.4987 - accuracy: 0.7595 - val_loss: 0.5520 - val_accuracy: 0.7437 - 528ms/epoch - 9ms/step
# Epoch 111/150
# 60/60 - 1s - loss: 0.4986 - accuracy: 0.7616 - val_loss: 0.5539 - val_accuracy: 0.7437 - 532ms/epoch - 9ms/step
# Epoch 112/150
# 60/60 - 0s - loss: 0.4984 - accuracy: 0.7584 - val_loss: 0.5536 - val_accuracy: 0.7437 - 499ms/epoch - 8ms/step
# Epoch 113/150
# 60/60 - 1s - loss: 0.4982 - accuracy: 0.7627 - val_loss: 0.5549 - val_accuracy: 0.7269 - 600ms/epoch - 10ms/step
# Epoch 114/150
# 60/60 - 1s - loss: 0.4977 - accuracy: 0.7605 - val_loss: 0.5542 - val_accuracy: 0.7395 - 588ms/epoch - 10ms/step
# Epoch 115/150
# 60/60 - 1s - loss: 0.4979 - accuracy: 0.7616 - val_loss: 0.5544 - val_accuracy: 0.7353 - 566ms/epoch - 9ms/step
# Epoch 116/150
# 60/60 - 1s - loss: 0.4973 - accuracy: 0.7616 - val_loss: 0.5538 - val_accuracy: 0.7437 - 507ms/epoch - 8ms/step
# Epoch 117/150
# 60/60 - 0s - loss: 0.4972 - accuracy: 0.7658 - val_loss: 0.5558 - val_accuracy: 0.7311 - 495ms/epoch - 8ms/step
# Epoch 118/150
# 60/60 - 0s - loss: 0.4969 - accuracy: 0.7605 - val_loss: 0.5551 - val_accuracy: 0.7395 - 476ms/epoch - 8ms/step
# Epoch 119/150
# 60/60 - 0s - loss: 0.4967 - accuracy: 0.7616 - val_loss: 0.5555 - val_accuracy: 0.7353 - 469ms/epoch - 8ms/step
# Epoch 120/150
# 60/60 - 0s - loss: 0.4964 - accuracy: 0.7616 - val_loss: 0.5554 - val_accuracy: 0.7395 - 480ms/epoch - 8ms/step
# Epoch 121/150
# 60/60 - 1s - loss: 0.4962 - accuracy: 0.7648 - val_loss: 0.5569 - val_accuracy: 0.7311 - 600ms/epoch - 10ms/step
# Epoch 122/150
# 60/60 - 0s - loss: 0.4960 - accuracy: 0.7605 - val_loss: 0.5571 - val_accuracy: 0.7311 - 479ms/epoch - 8ms/step
# Epoch 123/150
# 60/60 - 1s - loss: 0.4959 - accuracy: 0.7616 - val_loss: 0.5565 - val_accuracy: 0.7395 - 509ms/epoch - 8ms/step
# Epoch 124/150
# 60/60 - 1s - loss: 0.4957 - accuracy: 0.7605 - val_loss: 0.5559 - val_accuracy: 0.7437 - 511ms/epoch - 9ms/step
# Epoch 125/150
# 60/60 - 1s - loss: 0.4958 - accuracy: 0.7605 - val_loss: 0.5567 - val_accuracy: 0.7395 - 520ms/epoch - 9ms/step
# Epoch 126/150
# 60/60 - 1s - loss: 0.4952 - accuracy: 0.7627 - val_loss: 0.5580 - val_accuracy: 0.7311 - 504ms/epoch - 8ms/step
# Epoch 127/150
# 60/60 - 0s - loss: 0.4951 - accuracy: 0.7637 - val_loss: 0.5568 - val_accuracy: 0.7395 - 483ms/epoch - 8ms/step
# Epoch 128/150
# 60/60 - 1s - loss: 0.4948 - accuracy: 0.7648 - val_loss: 0.5582 - val_accuracy: 0.7311 - 543ms/epoch - 9ms/step
# Epoch 129/150
# 60/60 - 1s - loss: 0.4948 - accuracy: 0.7648 - val_loss: 0.5578 - val_accuracy: 0.7395 - 674ms/epoch - 11ms/step
# Epoch 130/150
# 60/60 - 1s - loss: 0.4945 - accuracy: 0.7627 - val_loss: 0.5580 - val_accuracy: 0.7395 - 749ms/epoch - 12ms/step
# Epoch 131/150
# 60/60 - 1s - loss: 0.4944 - accuracy: 0.7616 - val_loss: 0.5575 - val_accuracy: 0.7437 - 758ms/epoch - 13ms/step
# Epoch 132/150
# 60/60 - 1s - loss: 0.4941 - accuracy: 0.7616 - val_loss: 0.5581 - val_accuracy: 0.7395 - 1s/epoch - 19ms/step
# Epoch 133/150
# 60/60 - 1s - loss: 0.4939 - accuracy: 0.7616 - val_loss: 0.5585 - val_accuracy: 0.7395 - 1s/epoch - 22ms/step
# Epoch 134/150
# 60/60 - 1s - loss: 0.4940 - accuracy: 0.7637 - val_loss: 0.5594 - val_accuracy: 0.7395 - 1s/epoch - 23ms/step
# Epoch 135/150
# 60/60 - 1s - loss: 0.4937 - accuracy: 0.7627 - val_loss: 0.5602 - val_accuracy: 0.7311 - 1s/epoch - 21ms/step
# Epoch 136/150
# 60/60 - 1s - loss: 0.4933 - accuracy: 0.7637 - val_loss: 0.5589 - val_accuracy: 0.7395 - 1s/epoch - 19ms/step
# Epoch 137/150
# 60/60 - 1s - loss: 0.4934 - accuracy: 0.7605 - val_loss: 0.5598 - val_accuracy: 0.7395 - 1s/epoch - 21ms/step
# Epoch 138/150
# 60/60 - 1s - loss: 0.4930 - accuracy: 0.7627 - val_loss: 0.5598 - val_accuracy: 0.7395 - 1s/epoch - 19ms/step
# Epoch 139/150
# 60/60 - 1s - loss: 0.4931 - accuracy: 0.7616 - val_loss: 0.5612 - val_accuracy: 0.7311 - 1s/epoch - 19ms/step
# Epoch 140/150
# 60/60 - 1s - loss: 0.4929 - accuracy: 0.7648 - val_loss: 0.5586 - val_accuracy: 0.7479 - 1s/epoch - 19ms/step
# Epoch 141/150
# 60/60 - 1s - loss: 0.4930 - accuracy: 0.7616 - val_loss: 0.5591 - val_accuracy: 0.7479 - 1s/epoch - 19ms/step
# Epoch 142/150
# 60/60 - 1s - loss: 0.4924 - accuracy: 0.7627 - val_loss: 0.5604 - val_accuracy: 0.7395 - 1s/epoch - 22ms/step
# Epoch 143/150
# 60/60 - 1s - loss: 0.4924 - accuracy: 0.7637 - val_loss: 0.5604 - val_accuracy: 0.7395 - 1s/epoch - 21ms/step
# Epoch 144/150
# 60/60 - 1s - loss: 0.4921 - accuracy: 0.7648 - val_loss: 0.5598 - val_accuracy: 0.7479 - 1s/epoch - 22ms/step
# Epoch 145/150
# 60/60 - 1s - loss: 0.4919 - accuracy: 0.7658 - val_loss: 0.5606 - val_accuracy: 0.7395 - 1s/epoch - 25ms/step
# Epoch 146/150
# 60/60 - 1s - loss: 0.4921 - accuracy: 0.7627 - val_loss: 0.5613 - val_accuracy: 0.7395 - 1s/epoch - 24ms/step
# Epoch 147/150
# 60/60 - 1s - loss: 0.4918 - accuracy: 0.7605 - val_loss: 0.5610 - val_accuracy: 0.7437 - 1s/epoch - 21ms/step
# Epoch 148/150
# 60/60 - 1s - loss: 0.4915 - accuracy: 0.7637 - val_loss: 0.5621 - val_accuracy: 0.7395 - 1s/epoch - 19ms/step
# Epoch 149/150
# 60/60 - 1s - loss: 0.4914 - accuracy: 0.7574 - val_loss: 0.5627 - val_accuracy: 0.7311 - 1s/epoch - 19ms/step
# Epoch 150/150
# 60/60 - 1s - loss: 0.4912 - accuracy: 0.7627 - val_loss: 0.5619 - val_accuracy: 0.7395 - 1s/epoch - 18ms/step

# %% [markdown]
# ### Evaluate Testdata using model

# %%
pred = model.predict(nn_data_test["data"])
classes= [1 if i > 0.5  else 0 for i in pred]
# Out:
# 16/16 [==============================] - 0s 3ms/step

# %% [markdown]
# ### Prepare Data for evaluation

# %%
result_df = pd.DataFrame(columns=nn_data_raw_train.columns[:-1])

for i, row in enumerate(nn_data_test["data"]):
    data = [i,i]
    data.extend(row)
    result_df.loc[i+1] = data

result_df["LABEL"] = nn_data_test["target"]
result_df["PRED"] = classes

result_df.to_csv(result_dir / "DPP4/fe_smote_nn.csv", encoding="utf-8")
